# %% [markdown]
# # 02 · Preprocesamiento del corpus
#
# Aplica el pipeline definido en `src/preprocessing.py` y persiste `corpus.parquet`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

from src.data_loader import load_fake_real_news
from src.preprocessing import preprocess_dataframe, clean_text
from src import config

df = load_fake_real_news()
print('Original:', len(df))
df_clean = preprocess_dataframe(df)
print('Después de limpieza:', len(df_clean))
df_clean[['title','clean_text','label']].head(3)

# %%
# Comparación antes/después
for i in range(2):
    print('ORIG :', df.iloc[i]['text'][:200])
    print('CLEAN:', df_clean.iloc[i]['clean_text'][:200])
    print('-' * 80)

# %%
config.PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
df_clean.to_parquet(config.CORPUS_PATH, index=False)
print('Guardado en', config.CORPUS_PATH)
